# %% [markdown]
# # Assignment 2: Statistical inference
# ## [Scientific Computing with Python](https://scicompy.yoavram.com/)
# ## Yoav Ram

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.stats
import numpy as np
import pandas as pd
import emcee
from corner import corner
import seaborn as sns
sns.set_context('notebook')
sns.set_palette('muted')

import zipfile
import urllib.request
import os
import itertools

red, blue, green = sns.color_palette('Set1', 3)

# %% [markdown]
# # General instructions
#
# 1. When instructed to implement a function, use the given function names and parameters lists; failure to do so may cause test functions to fail during grading.
# 1. When instructed to generate a plot, make sure that the plot is clear, that axes are propely labeled, and that the notebook is saved with the plot inline, so that the grader can see the plot without running the code. Make sure that you re-generate the plot if you changed the code!
# 1. Code lines with a triple comment `###` should not be removed or modified, they are used for automatic grading.
# 1. Note that there are 2 exercises and the last cell in the notebook says **end of assignment**; if you are missing anything please download the origianl file from the course website.
# 1. This exercise doesn't put much emphasis on efficieny or runtime. *But*, your code should still run within a reasonable time (a few minutes) and you should use idioms learned in class, e.g. array opreations, wherever possible to "lose your loops".
# 1. Questions regarding the exercises should be posted to the course forum at the designated group (i.e. "assignment2"). You can post questions anonymously. You can also visit the Office Hours, but please do not email the course staff with questions about the exercise.
# 1. Intructions for submitting the exercise are on the [course website](https://scicompy.yoavram.com/assignments).

# %% [markdown]
# # Exercise 1

# %% [markdown]
# In this analysis we will compare the body temperature of animals to check if indeed there is such a thing as [warm-blooded](http://en.wikipedia.org/wiki/Warm-blooded) and cold-blooded animals.
#
# ## Data loading and preprocessing
#
# We start by loading the data.

# %%
###
url = 'http://genomics.senescence.info/species/dataset.zip'
fname = '../data/anage_dataset.zip'
if not os.path.exists(fname):
    urllib.request.urlretrieve(url, fname)
print("Data file exists:", os.path.exists(fname))
# Out:
# Data file exists: True

# %%
###
with zipfile.ZipFile(fname) as z:
    f = z.open('anage_data.txt')
    data = pd.read_table(f)

# %% [markdown]
# The temperatures are in Kelvin degrees in the `Temperature (K)` column, and we like Celsius degrees.
# So we transform the temperature to Celsius and save the result in a new column.
#
# Note: SciPy has a special function for Kelvin to Celsius conversion.

# %%
###
from scipy.constants import convert_temperature
data['Temperature (C)'] = convert_temperature(data['Temperature (K)'], 'K', 'C')

# %% [markdown]
# Next, we clean the data frame from rows with missing values in the temperature column.
# We remove from the data classes with fewer than 10 species -- these are the birds.

# %%
###
data = data[np.isfinite(data['Temperature (C)'])]
data['Class'].value_counts()
# Out:
# Mammalia    457
# Amphibia     18
# Reptilia     16
# Aves          3
# Name: Class, dtype: int64

# %%
data = data[data["Class"] != 'Aves'] ###

# %% [markdown]
# We are left with mammals, reptiles, and amphibians.
#
# We collate together the non-mammals (reptiles and amphibians).

# %%
mammals = data['Class'] == 'Mammalia' ###

# %% [markdown]
# **Plot a histogram of the temperature**: one histogram for mammals, and one histogram for amphibians and reptiles.
#
# Plot the histograms on the same figure. Use `density=True` so that the histograms will be normalized, since there are many more mammals.

# %%
plt.hist(data[mammals]['Temperature (C)'], density=True, alpha=0.7, label='Mammals')
plt.hist(data[~mammals]['Temperature (C)'], density=True, alpha=0.7, label='Others')
plt.xlabel('Temperature (C)')
plt.ylabel('Density')
plt.legend();

# %% [markdown]
# ## Frequentist approach: t-test
#
# OK. Now we want to compare these two empirical distribution: do they come from the same distribution? What is the probability that there is no difference between mammals and amphibians/reptiles, and that the difference we see in the dataset is a fluke?
#
# The standard frequntist approach for this is [Student's t-test](https://en.wikipedia.org/wiki/Student%27s_t-test), which is used _"to determine if the means of two sets of data are significantly different from each other."_
#
# This test assumes that the data are normally distributed around the mean (the histogram looks OK, I guess), but it also assumes that the variance is equal in the two distibutions, which doesn't seem to be the case.

# %% [markdown]
# A more robust test is [Welch's t-test](https://en.wikipedia.org/wiki/Welch%27s_t-test).
# The test statistic is defined as:
# $$
# t=\frac{\bar{X}_{1}-\bar{X}_{2}}{\sqrt{\frac{s_{1}^{2}}{N_{1}}+\frac{s_{2}^{2}}{N_{2}}}},
# $$
# where $X_i$ is dataset $i$, $\bar{X}_i$ is it's mean, $s_i$ it's standard deviation, and $N_i$ it's size.

# %% [markdown]
# The numerator is just the difference in means - we want to test if this is dignificantly different than zero.
# The denominator scales the mean difference using an estimate of the standard errors of the means.
#
# Welch's test assumes normality, but not equal variance.
#
# **Compute $t$ and print it.**

# %%
X1 = data.loc[mammals, 'Temperature (C)'].values ###
X2 = data.loc[~mammals, 'Temperature (C)'].values ###

X1_hat, s1, N1 = X1.mean(), X1.std(ddof=1), X1.shape[0]
X2_hat, s2, N2 = X2.mean(), X2.std(ddof=1), X2.shape[0]

t = (X1_hat - X2_hat) / np.sqrt((np.power(s1, 2) / N1) + (np.power(s2, 2) / N2))

print('t = {:.3f}'.format(t)) ###
# Out:
# t = 16.454

# %% [markdown]
# Welch showed that that $t$ is approximately t-distributed:
#
# $$
# t \sim \mathbb{t}(\nu)
# $$
#
# where the parameter $\nu$ for the distribution of $t$ is
# $$
# \nu \approx \frac{\left(\frac{s_{1}^{2}}{N_{1}}+\frac{s_{2}^{2}}{N_{2}}\right)^{2}}{\frac{s_{1}^{4}}{N_{1}^{2} \nu_{1}}+\frac{s_{2}^{4}}{N_{2}^{2} \nu_{2}}}
# $$
# where $\nu_i = N_i-1$. We won't get into how this is all constructed -- this requires some mathematical abckground.
#
# However, we will compute the probability to draw from $\mathbb{t}(\nu)$ a value as extreme as $t$.
# We will print this probability, which is commonly called the _p-value_ of the test.
#
# This p-value tells gives us what we were looking for: the probability that the two distributions actually have the same mean, despite the disparity we see.
# As you will see, the p-value is extremely low, and therefore we can reject the hypothesis (which is usually called the null hypothesis) that there is no difference between the temperature of mammals and amphibians/reptiles.
#
# _Note:_ we use `scipy.stats.t.sf(x) * 2` (`sf(x) = 1 - cdf(x)`), which returns the probability to get a value as extreme (very large or very small) as `x`. This "very small or very large" is considered a two-sided test: we want to if either mean is much greater than the other one.

# %%
###
ν = (s1 * s1 / N1 + s2 * s2 / N2)**2 / (s1**4 / (N1*N1*(N1-1)) + s2**4 / (N2 * N2 * (N2-1)))

pvalue = scipy.stats.t.sf(t, ν) * 2
print('p-value: {:.2g}'.format(pvalue))
# Out:
# p-value: 1.4e-17

# %% [markdown]
# By the way, we could have just used `scipy.stats.ttest`. Here's how to do that:

# %%
###
t, pvalue = scipy.stats.ttest_ind(X1, X2, equal_var=False)
print("P-value: {:.2g} (t={:.3f})".format(pvalue, t))
# Out:
# P-value: 1.4e-17 (t=16.454)

# %% [markdown]
# ## Bayesian approach: BEST
#
# Now let's do this using Bayesian statistics, with an approach called BEST ([Bayesian Estimation Supersedes the T-test](https://psycnet.apa.org/fulltext/2012-18082-001.pdf)).
#
# The nice thing is that once we understand Bayesian inference, we can easily understand BEST; whereas with the t-test, we need to specifically understand t-distributions, which looks very complicated.
#
# How are we modelling the data?
# Similarly to the t-test, we assume normality:
#
# $$
# X_1 \sim N(\mu_1, \sigma_1^2) \\
# X_2 \sim N(\mu_2, \sigma_2^2)
# $$
#
# So the model parameters are $\theta=(\mu_1, \mu_2, \sigma_1, \sigma_2)$.
#
# **Start by infering $\theta$** using _emcee_ (or your own MCMC code if you prefer).
#
# To have a full description of our model we need to specify the prior for $\theta$.
# We provide wide priors for $\mu_i$ around the sample mean, and some exponential prior for the standard deviation terms:
#
# $$
# \mu_i \sim N(\bar{X}, 1000), \\
# \sigma_i \sim Exp(10)
# $$
#
# here $\bar{X}$ is the mean of all the samples (including all of $X_1$ and $X_2$), and $Exp(10)$ is an exponential distribution with mean 10 (implemented with `scipy.stats.expon(scale=10)`).

# %%
X = np.concatenate((X1, X2)) ###
Xbar = X.mean() ###


def log_prior(θ): ###
    μ1, μ2, σ1, σ2 = θ
    return \
        scipy.stats.norm(Xbar, 1000).logpdf(μ1) + \
        scipy.stats.norm(Xbar, 1000).logpdf(μ2) + \
        scipy.stats.expon(scale=10).logpdf(σ1) + \
        scipy.stats.expon(scale=10).logpdf(σ2)

def log_likelihood(θ, X1, X2): ###
    μ1, μ2, σ1, σ2 = θ
    return \
        -0.5 * (np.log(2 * np.pi * (σ1**2)) + (X1 - μ1) ** 2 / (σ1**2)).sum() + \
        -0.5 * (np.log(2 * np.pi * (σ2**2)) + (X2 - μ2) ** 2 / (σ2**2)).sum()

def log_posterior(θ, X1, X2): ###
    logpr = log_prior(θ)
    if np.isinf(logpr): 
        return logpr
    else: 
        return logpr + log_likelihood(θ, X1, X2)

# %%
ndim = 4
nwalkers = 50
nsteps = 500
guesses = np.random.rand(nwalkers, ndim) ###
guesses[:, :2] *= 2000  # start mu between 0 and 2000
guesses[:, 2:4] *= 20    # start sigma between 0 and 20

# %%
sampler = emcee.EnsembleSampler(
    nwalkers=nwalkers, 
    ndim=ndim,
    log_prob_fn=log_posterior,
    args=[X1, X2]
)
sampler.run_mcmc(
    initial_state=guesses,
    nsteps=nsteps
)
# Out:
# State([[36.56078582 17.75641611  1.79378064  5.35108147]
#  [36.64534305 18.63686718  1.76208187  5.42940472]
#  [36.45684701 19.72909992  1.83666605  5.71934719]
#  [36.63729452 21.02603509  1.70615277  6.30089154]
#  [36.45646271 20.64382918  1.81771937  5.96501554]
#  [36.60260774 18.76638125  1.73470887  7.90838442]
#  [36.56752721 19.63519188  1.68731175  6.66626468]
#  [36.52080593 19.81997349  1.80293101  5.52019857]
#  [36.71070005 20.50732751  1.83848387  5.99495479]
#  [36.54306102 19.88804881  1.7728745   7.1615764 ]
#  [36.59893106 16.70608822  1.76437018  7.44822473]
#  [36.59385571 19.27177301  1.78906099  6.24482431]
#  [36.75590424 20.5003503   1.81444267  7.08545728]
#  [36.51184455 19.94814794  1.77203571  5.73971492]
#  [36.57032696 19.2328933   1.76644656  7.42612434]
#  [36.62169765 18.81980249  1.7820008   6.57181571]
#  [36.42757432 18.84974842  1.75898058  6.74997682]
#  [36.54092789 19.40264774  1.78322206  5.50478898]
#  [36.5350135  20.17899781  1.71792345  6.33964367]
#  [36.71796604 18.81009418  1.67332769  7.07388376]
#  [36.63785232 19.61101836  1.78397541  5.46534127]
#  [36.47232057 21.22725725  1.70735589  9.20393649]
#  [36.64173353 19.47170467  1.79969612  6.1495066 ]
#  [36.61636376 19.68287253  1.85148886  6.53552191]
#  [36.59839615 19.39657628  1.80090302  5.97348212]
#  [36.60984193 17.37133722  1.75625816  7.00724087]
#  [36.54605067 18.7385094   1.88199618  7.57188524]
#  [36.48054282 18.97024098  1.7198587   6.15740645]
#  [36.6999382  17.80201609  1.62846802  6.6054529 ]
#  [36.4497169  20.17281766  1.69403652  5.41362838]
#  [36.59054349 20.05062384  1.78788278  5.38427064]
#  [36.56885343 18.69578878  1.72428712  5.71420345]
#  [36.41786041 20.71115498  1.76384383  7.41728669]
#  [36.53801391 21.97847495  1.81438285  6.63800013]
#  [36.57543065 19.95087086  1.6572884   5.62834033]
#  [36.68647485 18.93161424  1.75532884  6.3529443 ]
#  [36.47941748 19.6662475   1.78783536  5.98473386]
#  [36.66577054 21.92412147  1.7585325   6.80117527]
#  [36.67479479 19.0389621   1.71393903  6.24478128]
#  [36.63087563 19.67440698  1.81765077  4.9743502 ]
#  [36.55704258 17.97629455  1.6924929   7.11071799]
#  [36.56646768 20.02086668  1.75512957  5.06711478]
#  [36.60136789 21.48133679  1.71562055  5.13837557]
#  [36.48324039 19.27957508  1.83380189  5.62839365]
#  [36.78188523 19.17397959  1.80549456  5.07841729]
#  [36.72606098 19.34654527  1.80372491  6.12565926]
#  [36.78556187 20.39971278  1.87920202  6.72588127]
#  [36.5636645  19.08704354  1.85824666  6.36292943]
#  [36.50972166 20.74317103  1.69923101  5.76039725]
#  [36.58371939 18.32384268  1.83986565  4.99894881]], log_prob=[-1037.50185225 -1035.93640802 -1036.8194185  -1036.42564625
#  -1036.93839437 -1037.7812052  -1036.09544002 -1035.54471514
#  -1037.32532701 -1036.26841735 -1039.29792624 -1035.22819556
#  -1038.87327034 -1035.26702715 -1036.63703885 -1035.78540685
#  -1037.45658587 -1035.22193524 -1035.51695445 -1038.784207
#  -1035.35358547 -1042.03804422 -1035.49369885 -1036.61683267
#  -1035.21068327 -1037.72336235 -1039.31781789 -1036.07168315
#  -1040.52175979 -1037.10833712 -1035.33263029 -1035.46082916
#  -1038.83306424 -1038.07177898 -1036.44013614 -1036.11241979
#  -1035.73751898 -1037.99106818 -1036.07640134 -1036.57286348
#  -1037.59644586 -1035.69953694 -1037.8518264  -1036.47134075
#  -1038.95126583 -1036.78847745 -1040.47689068 -1036.69242917
#  -1036.29543954 -1037.9841809 ], blobs=None, random_state=('MT19937', array([2432403039, 3826143810, 3877726546, 2832440056, 1515605454,
#        3600954895, 1209352155, 1749664014, 3202136597, 3832737814,
#        2759598581, 2122117906, 4233205974,  376887836, 3585492800,
#        3426833981, 2461692637, 2585909382, 1573976102,  752582919,
#        2042518101, 4180915262, 1124678829, 2801032841, 3721565556,
#        3320520664,   73691607, 3450430499, 3620428903, 3507560877,
#        2078808506,  812670112, 3058627792, 2876962354, 3977571275,
#         736188225, 3027367308, 4209892080, 3075960088, 2246262537,
#        3619668246,  195024152, 2348229319,  942566295, 3157465488,
#          29401891,  756436950, 2842248875,  641148492, 2053908267,
#        1324395491, 3139644637, 4029698730,  529031870, 2262041845,
#        3966558039, 2196322386, 3112195538,  278670155, 3603081604,
#        4036105997, 1962403243, 2680456076, 2332147083, 3113109588,
#        3239760778, 4100770102, 2847557982, 2355925629, 3412849387,
#        1181085390, 3781126552, 3743955641, 3537889717,  662752648,
#        4072189177, 4224896072, 3568587397,  432385929, 2632783007,
#        3481675855,   16027451, 2264028549, 2337824428, 2207066117,
#        1757519737, 1682174549,  849745338, 3177287809,  342508131,
#        2709029670, 3279624149, 3237441241,  291289496, 2695932630,
#        3870175569,  910553701, 4086634693, 1441082794,  730056801,
#        3396665575,  492289334, 1157247693, 2923378006,  684445138,
#        1808156636, 4169753926, 1755548765, 1770211155,  629131996,
#        3796005258, 3102191282, 2526295640,  467997113, 2328930355,
#         483935765, 2021410898, 1124471777, 4098433149, 3493787992,
#        3929554919, 3182650684, 2168903809, 3121172346,  823848791,
#         421379205, 1580399019, 1954567683, 2183869220,  365028708,
#        4158939608, 2661012679, 3010442483, 3029152691, 1859340622,
#        2835015817,  294576149, 2625505349, 1512784324,  849303534,
#        1451237368, 2849168600, 1359998841,  486439301,  550999968,
#        3517495729, 2373776133, 3024538320,  753112705, 3787663903,
#        2283354551, 3413545753, 3605813283, 3116308493, 2573819505,
#        1732338984,  699910064, 1596281064, 1958800916,  613395132,
#        2613708212, 1154323173,  379669002, 1245494235, 2288905247,
#          80879836, 2158487145, 1933389394,  663229724, 3665667506,
#        1430044807, 3671503001,  985049490, 4089737727, 2412551388,
#        1584586158, 3068681693, 3192086149, 3673155848, 2316467315,
#        2129035520, 3049147351, 4142063016, 3851637506, 2368528192,
#        2837849267, 3823872973, 2727163803,  820595712, 1792904961,
#         664216158, 3268036186, 2361164630, 4251347479, 3668943112,
#        1714777948, 2914490458, 1308213972, 2769874340, 1319113605,
#        1747375705, 4258363436, 2914611778, 3630946677,  909393402,
#         969179951,  856431931, 3971326699, 4289298826, 3878003777,
#        2328832176, 3802111333, 2399300572,  878839430,   52487757,
#         979305211, 2367095744,  224387727,  197851956, 1387506085,
#         157019806,  759393962, 3120910812, 1537785357, 2844430580,
#        3019547300, 3570581893, 1397829567, 1329226552, 1729205658,
#        2409837516, 3328857016, 2514011242, 1208950517, 3943357710,
#         418262492, 4125525151,  613391479, 1823059002,  612191493,
#        3124389267, 1742491529, 2561555055, 2876788926, 2981750383,
#          37243422, 2718032372, 3689552660, 3582428150,  444475019,
#        3342376128, 3194428633, 3351457847, 2216022854, 1291733337,
#        2155533334, 4183514709, 4154434047, 3862848578,  872505133,
#        3487686965, 3020034516,  315960916, 4251633120,  891563598,
#        3616677180,   57682099, 2226791766, 4243432387, 3012539397,
#         676843083, 1425271418, 2013511600,  334322355, 3718854325,
#        2240318633, 3164955174,  595006649, 4102986773, 3624429767,
#         493212175, 2593820390, 1802320796, 3547937524, 3940204171,
#        1904532376,  907361894,  461420663, 1246172668,  758910462,
#         957967097,  283970572, 1858868890, 1130078540, 1101271149,
#         709940788, 1299555617, 1578350733, 3135923005, 3657948136,
#        2493757287, 2620043996, 2837530584, 1835713029, 2179820784,
#        2911411375, 4092835724, 2302778631, 1690030344, 3397178612,
#        3498159656,  248039592, 4143241075,  118086520,  880810794,
#        2886260864,  432107030,   61289651, 4172364301,  151267320,
#        3497140641, 2720965836, 1279817712, 2675712638,  630012210,
#         688320755,  669130277,  175278909, 4008865922, 3465425906,
#         484548471, 2912988251, 3317496004, 2635360403, 1739401860,
#        2608255469,  141485750, 3348618790,  743318288, 1504856893,
#         345332238,  435441391, 1183559533, 3920092905, 2769361012,
#        1475507495, 2062755500,  275074045, 3516683753,  333943343,
#         778338363, 1530439134, 1150290807, 2578553947,  330823944,
#         709627844,  651613805, 3200576040,  188888821, 3057340592,
#        3799933474,  210661637, 2477039523, 3505485706, 3280654912,
#        3338006611, 2137286000, 3457836481, 3799812207, 1316844830,
#        1097357299, 1521843163, 2202816242, 2096546612, 2304649131,
#         787574886, 1241612622, 1027677537, 3199632082,   22313912,
#        2446394246,  457285838, 2244423585, 3946857033, 3554683714,
#        2303462812, 4227259736, 4197093708, 1568347005,  938491790,
#        4236783742, 3373034092, 3318877816, 2186673742,  407686004,
#        1994638017, 2393852987, 3189680252, 3193098522,  519806544,
#        4060710737, 1719873651, 2338430572, 3747653641, 3040873620,
#        3999276550,  449820544, 4172968437, 3866834322, 3593197215,
#        3061360142, 3984465673, 2820301807,   58023716, 1277231197,
#         103701438, 3152359460, 2100178403, 2194603531, 1659390094,
#        2799169189,  447020748, 2016663819, 2809237236, 3116114375,
#         288119027, 2922918451,  598891919, 1493116467, 2398918502,
#        3220716600,  614657530, 3139746837, 2823818871, 1562317694,
#        1539800247, 1547219651, 2309928964, 1932079352, 2216557847,
#        2145392559, 1381729430, 3347661670, 1911517075, 3525865332,
#        2489591711, 1045062823, 3041253805, 3442472549,   19848720,
#        1057417129, 1432726851,   95851619, 2560603635, 2533125283,
#        1378474516, 2219646243, 3121464180,  849985397, 1852161755,
#        4103925671, 3824007336, 2051770221,  804771517, 2965871515,
#          61098183, 1987318973, 2181348648, 1009545014,  795089347,
#        3649050315,  699926781, 1376963997, 1415210051, 3027666718,
#         374224545, 2050971697,  769122347, 1709976801, 1198095011,
#         643444580, 2450934099,  593716860, 3903705254,  767670323,
#        2679641062, 1814147800, 1120366342, 1882936741,  329884352,
#         410508631, 1490005227, 3112291911, 3522379889, 3899140606,
#        3519797341, 3916337611, 2252365748, 2851496201, 3369656036,
#        2162213218,  536276201, 4246359092,  268719581,  171721562,
#           8162747, 3804434623, 2244704437,  160759178, 1668467304,
#        1485133640, 2671994140, 1822640693, 1836577273, 3179466365,
#         284445274, 3798904928, 1764961738, 3782666092, 1793691356,
#        3195044037,  936556421, 2572133050, 1096938663, 1278203543,
#        3294340715, 1720827273, 1562955675,   57800044, 4072798840,
#        1864500078, 3215497636, 4252009621, 4226339175,  579651120,
#        3093034914,  687326226, 1457918066, 3864341871, 3005579658,
#         578644541, 2065087387, 4193508256, 1016311366,  255860123,
#        1854759199,  862902675, 1577097393, 4209458925, 1742394004,
#        2690866286,  578838482, 1769147802, 1482922697, 2367809488,
#         124076627, 1684542784, 2307491659, 2726981637, 3751082759,
#        2227476954,  990729212,  740804888, 2039490129, 2897689810,
#        3253683131, 3307769051, 3211006068, 1644177145, 1904568194,
#         998430725, 3865729668, 1647988405, 1934131218, 1629242652,
#         353684665,  639971721, 1686073192,  777920321, 1545225662,
#        1574438928, 1634866563, 1521760086, 1601850491, 1869787910,
#        1748512853,   21395340, 3248522242, 3829697891, 2710032764,
#        2660228894, 2906046003, 1746848241, 2096775368,   45530272,
#         951095738, 2834919364, 1208863163, 1099958988, 3293672029,
#        1282136247, 2783720571,  476458417,  606662731, 3266876894,
#         958384481, 1609343282,  336338881,  480160514,  784594205,
#         421893679,  901656936, 1240837197, 1150723767, 3037982944,
#        3325832346,  228024289,  277491577, 4072163180, 1565568041,
#        3657680096,  748214560,   59377835, 1608138699], dtype=uint32), 180, 0, 0.0))

# %%
###
fig, axes = plt.subplots(1, 4, figsize=(14, 3), sharex=True)

for i, label in enumerate(['μ1', 'μ2', 'σ1', 'σ2']):
    for j in range(nwalkers):
        axes[i].plot(sampler.chain[j, :, i])
        axes[i].set_ylabel(label)
fig.tight_layout()

# %% [markdown]
# After inferring the parameters, we plot a trace plot to make sure the Markov chain has converged.

# %% [markdown]
# **Take the samples after the burnin period** and reshape if required (for example if you used more then one chain/walker).

# %%
nburn = nsteps // 2
sample = sampler.chain[:, nburn:, :].reshape(-1, ndim)

# %% [markdown]
# **Plot a corner plot** to examine the posterior. It should show nice gaussians, both on and off the diagonal.

# %%
cor = corner(sample, 
    smooth=True,
    labels=['μ1', 'μ2', 'σ1', 'σ2'],
    show_titles=True,
)

# %% [markdown]
# Finally, we can do the Bayesian estimation for the difference between the means $\mu_1$ and $\mu_2$ by computing the posterior of the difference $\Delta\mu = \mu_1 - \mu_2$:
# - **compute the difference** between the posterior samples of $\mu_1$ and $\mu_2$ to get posterior samples of $\Delta\mu$,
# - **plot the histogram of the posterior** of $\Delta\mu$ (note how far the distribution is from zero!),
# - **print the probability that $\mu_1>\mu_2$** according to the posterior of $\Delta\mu$.

# %%
delta_𝜇 = sample[:,0] - sample[:,1]
plt.hist(delta_𝜇.reshape(-1), density=True, bins=50)
plt.xlabel(u'Δ𝜇')
print(f"P(μ1 > μ2) = {(delta_𝜇 > 0).sum() / len(delta_𝜇):.2f}")
# Out:
# P(μ1 > μ2) = 1.00

# %% [markdown]
# We therefore infer that $P(\mu_1 > \mu_2) \approx 1$, that is, that the _mean temperature of mammals is larger than that of amphibians/reptiles with very high confidence_.

# %% [markdown]
# # Exercise 2
#
# In this exercise we will attempt to model the number of days between COVID-19-related hospitalization and death, and infer the model parameters from data.
#
# The data was recorded in Hubei province of China, and retrieved from [Xu & Kraemer, Lancet 2020](https://doi.org/10.1016/S1473-3099(20)30119-5).
#
# The data was filtered to include data for patients that were admitted to hospitals in Hubei (mostly Wuhan) during Jan 2020 and that died in the hospital.

# %%
###
df = pd.read_csv('../data/covid-19_line_list_Hubei_9Feb.csv', index_col=0)
df
# Out:
#     date_admission_hospital outcome date_death_or_discharge
# 60               16.01.2020    died              20.01.2020
# 62               18.01.2020    died              19.01.2020
# 64               03.01.2020    died              15.01.2020
# 65               05.01.2020    died              18.01.2020
# 66               11.01.2020    died              20.01.2020
# 67               14.01.2020    died              21.01.2020
# 69               18.01.2020    died              22.01.2020
# 70               06.01.2020    died              22.01.2020
# 71               11.01.2020    died              21.01.2020
# 72               18.01.2020    died              22.01.2020
# 73               13.01.2020    died              21.01.2020
# 74               09.01.2020    died              21.01.2020
# 75               13.01.2020    died              21.01.2020
# 76               09.01.2020    died              22.01.2020
# 214              19.01.2020    died              23.01.2020
# 215              05.01.2020    died              24.01.2020
# 216              18.01.2020    died              23.01.2020
# 217              17.01.2020    died              24.01.2020
# 218              19.01.2020    died              24.01.2020
# 219              19.01.2020    died              23.01.2020
# 220              19.01.2020    died              21.01.2020
# 221              18.01.2020    died              24.01.2020
# 222              11.01.2020    died              21.01.2020
# 223              23.01.2020    died              24.01.2020
# 224              16.01.2020    died              23.01.2020
# 225              15.01.2020    died              24.01.2020
# 226              01.01.2020    died              23.01.2020
# 227              12.01.2020    died              23.01.2020
# 228              17.01.2020    died              23.01.2020
# 230              14.01.2020    died              22.01.2020
# 231              09.01.2020    died              23.01.2020
# 232              05.01.2020    died              22.01.2020
# 233              21.01.2020    died              23.01.2020
# 234              13.01.2020    died              21.01.2020
# 547              13.01.2020    died              23.01.2020

# %% [markdown]
# - **Convert the date columns to `datetime`**
# - **Compute the array `X`** of the number of days in the hospital for each patient.
# - **Plot a histogram of `X`**; make sure to add axes labels.

# %%
df['date_admission_hospital'] = pd.to_datetime(df['date_admission_hospital'], format='%d.%m.%Y')
df['date_death_or_discharge'] = pd.to_datetime(df['date_death_or_discharge'], format='%d.%m.%Y')

X = (df['date_death_or_discharge'] - df['date_admission_hospital']).dt.days.values

plt.hist(X);
plt.xlabel('Days in hospital')
plt.ylabel('Frequency');

# %% [markdown]
# A good model for the number of days before death is the [Weibull distribution](https://en.wikipedia.org/wiki/Weibull_distribution), which is commonly used to model time-to-failure.
# In Weibull, the failure rate, or the probability for failure per time unit, is proportional to a power of time.
#
# Weibull has two parameters:
#
# - $\lambda$ is the basic failure rate
# - $k$ is the power plus one; therefore,
#  - when $k<1$ the failure rate decreases with time; this occurs for example with infants (in general, not connected to COVID-19)
#  - when $k=1$ the failure rate is constant in time; this corresponds to the exponential distribution and might occur if external factors unrelated to time are more important.
#  - when $k>1$ the failure rate increases with time; this occurs for example if the available treatments are limited (as was the case in January), or if the hospital stay itself added risk.

# %% [markdown]
# The probability function of a Weibull distribution with parameters $\lambda$ and $k$ is
#
# $$
# P(x \mid \lambda, k) = \begin{cases}
# \frac{k}{\lambda} \big(\frac{x}{\lambda}\Big)^{k-1} \exp\Big[{-\big(\frac{x}{\lambda}\big)^k}\Big], & x \ge 0, \\
# 0, & x < 0
# \end{cases}
# $$
#
# _Note 1_ that $k$ and $x$ look similar, so avoid making mistakes!
#
# _Note 2_ This $P(x \mid \lambda, k)$ gives you the likelihood of $(\lambda, k)$ given $x$; this is not the log-likelihood!
#
# **Implement the log-likelihood function `log_likelihood(θ, X)`** for the Weibull distribution, $\logP(X \mid \lambda, k)$.

# %%
def log_likelihood(θ, X): ###
    𝜆, 𝑘 = θ
    xrange = np.arange(1, 10000 + 1)
    c = np.sum(np.power(xrange, k-1)*np.exp(-np.power(xrange/𝜆, k)))
    return \
        (k-1) * np.sum(np.log(X[np.where(X > 0)])) \
        - 1/𝜆**k * np.sum(np.power(X, k)) \
        - len(X) * np.log(c)

# %% [markdown]
# We now compute the log-likelihood for a range of $\lambda$ values and for the following $k$ values: $k=0.1$, $k=1$ (exponential distribution), $k=2$, and $k=4$.
#
# We plot all the log-likelihoods we computed as a function of $\lambda$.

# %%
###
λ_range = np.linspace(X.min(), X.max()) 

# Exponential = Weibull k=1
ll_expon = [log_likelihood((λ_, 1), X) for λ_ in λ_range]

# Weibull
ll_weibull01 = [log_likelihood((λ_, 0.1), X) for λ_ in λ_range]
ll_weibull2 = [log_likelihood((λ_, 2), X) for λ_ in λ_range]
ll_weibull4 = [log_likelihood((λ_, 4), X) for λ_ in λ_range]

# %%
plt.plot(λ_range, ll_expon, label='Exponential')
plt.plot(λ_range, ll_weibull01, label='Weibull k=0.1')
plt.plot(λ_range, ll_weibull2, label='Weibull k=2')
plt.plot(λ_range, ll_weibull4, label='Weibull k=4')
plt.ylim(-300, -100)
plt.xlabel('λ')
plt.ylabel('Log-likelihood')
plt.legend()
sns.despine()

# %%
plt.plot(λ_range, ll_expon, label='Exponential')
plt.plot(λ_range, ll_weibull01, label='Weibull k=0.1')
plt.plot(λ_range, ll_weibull2, label='Weibull k=2')
plt.plot(λ_range, ll_weibull4, label='Weibull k=4')
plt.ylim(-300, -100)
plt.xlabel('λ')
plt.ylabel('Log-likelihood')
plt.legend()
sns.despine()

# %% [markdown]
# The above plot shows that the maximum likelihood estimate for $k$ is likely higher than 1 and lower than 4.
# Therefore, the exponential distribution ($k=1$) is likely inappropriate, and the **death rate likely increases every day in the hospital**.
#
# Next, **compute the log-likelyhood for combinations of $\lambda$ and $k$ values**, and **find and print the MLE** (maximum likelihood estimate).
#
# Then use the provided code to plot the log-likelihood plane and mark the MLE with green marker.
#
# _Tip:_ when using `pcolormesh`, it is useful to manually set `vmin` and `vmax` to meaningful values; otherwise, extremely low log-likelihood will cause most of the plane to be of the same color. This is similar to manually setting `ylim` in the previous plot.

# %%
λ_range = np.linspace(X.min(), X.max(), 100) ###
k_range = np.linspace(1, 4, 51) ###
values = list(itertools.product(λ_range, k_range))

loglik = np.array([log_likelihood((𝜆, 𝑘), X) for 𝜆, 𝑘 in values])
λ_hat, k_hat = values[loglik.argmax()]

print('λ_hat = {:.2f}, k_hat={:.2f}'.format(λ_hat, k_hat)) ###
# Out:
# λ_hat = 9.48, k_hat=1.72

# %%
###
plt.pcolormesh(λ_range, k_range, loglik.reshape(51, 100), cmap='autumn', vmin=-150, vmax=-100, rasterized=True)
plt.plot(λ_hat, k_hat, '*', markersize=10, color=green)
plt.xlabel('λ')
plt.ylabel('k')
plt.colorbar(label='Log-likelihood');

# %% [markdown]
# Now, we will estimate the joint posterior of $\lambda$ and $k$ using _emcee_.
#
# - **Define `log_prior` and `log_posterior`**.
# - **Make guesses of $\lambda$ and $k$ for each emcee walker** using the log-likelihood plots from above.
# - **Run the emcee sampler to get samples from the posterior**.
#
# Note: you can define the prior as a uniform in some range, consult with the log-likelihood plot above for an appropriate range.

# %%
def log_prior(θ): ###
    λ, k = θ
    return \
        scipy.stats.uniform(loc=4, scale=20).logpdf(λ) + \
        scipy.stats.uniform(loc=1, scale=2).logpdf(k)

def log_posterior(θ, X): ###
    logpr = log_prior(θ)
    if np.isinf(logpr):
        return logpr
    else:
        return logpr + log_likelihood(θ, X)

# %%
ndim, nwalkers = 2, 50
nsteps, nburn = 1000, 250

guesses = np.random.rand(nwalkers, ndim)
guesses[:, 0] *= 10
guesses[:, 1] *= 2

sampler = emcee.EnsembleSampler(
    nwalkers=nwalkers, 
    ndim=ndim,
    log_prob_fn=log_posterior,
    args=[X]
)
sampler.run_mcmc(
    initial_state=guesses,
    nsteps=nsteps
)
# Out:
# State([[10.09089181  1.85955166]
#  [ 8.54759659  2.07406807]
#  [10.48901428  1.89664083]
#  [ 8.14417999  1.74536791]
#  [ 8.1557178   1.60677517]
#  [ 8.62173183  1.51782601]
#  [10.08706181  1.5701717 ]
#  [ 9.88957443  1.50138429]
#  [ 9.24160383  1.77729665]
#  [ 9.61014537  1.7881609 ]
#  [ 9.88823805  1.70609249]
#  [10.66414981  1.50688475]
#  [10.35758537  1.33395144]
#  [ 8.13799304  1.73644241]
#  [10.72839906  1.98413973]
#  [ 9.7596931   2.08237847]
#  [10.59143906  1.90036123]
#  [10.14701312  1.3503683 ]
#  [10.28652129  1.82013786]
#  [ 8.82753222  1.79201122]
#  [ 8.58283445  1.7714165 ]
#  [10.22462364  2.07476591]
#  [ 8.0656693   1.73567282]
#  [ 9.58925155  1.94284806]
#  [ 9.70253106  2.10041315]
#  [ 8.94380735  1.49288602]
#  [ 8.58563907  1.83532779]
#  [ 9.45569823  1.44802797]
#  [ 9.26889744  1.42270491]
#  [10.59593609  1.99380158]
#  [ 9.92237989  1.83705426]
#  [ 8.57445789  1.59898069]
#  [ 8.69179805  1.53274307]
#  [13.10203002  1.97258685]
#  [11.08915736  1.81098765]
#  [10.56099756  1.40314157]
#  [ 8.20815542  1.55498705]
#  [ 7.97728245  1.76489263]
#  [10.62617044  2.46639664]
#  [ 9.08693009  1.80310961]
#  [10.28791666  1.82809578]
#  [ 7.62258959  1.30596212]
#  [11.60438448  1.39133687]
#  [ 9.42029037  2.08938943]
#  [12.77792106  2.33299752]
#  [ 9.90856123  1.74193786]
#  [ 9.9375716   1.89070364]
#  [ 9.43484431  1.54785771]
#  [ 9.89176711  1.81134864]
#  [ 8.68573216  1.77160108]], log_prob=[-106.91677578 -109.59600078 -107.25014409 -108.0847899  -107.61950586
#  -107.15909878 -107.13447484 -107.28069507 -106.74653822 -106.69147236
#  -106.74552142 -107.88135865 -108.67335922 -108.05550026 -107.69934208
#  -107.72282752 -107.34853089 -108.37553827 -106.98234189 -107.09726355
#  -107.35210808 -107.69931437 -108.22546532 -107.08456591 -107.85731606
#  -107.10647316 -107.62180064 -107.34886291 -107.4390972  -107.60469873
#  -106.81223477 -107.08481994 -107.0835664  -111.87217282 -107.79887155
#  -108.35395831 -107.50860605 -108.63332005 -110.77391527 -106.88858861
#  -106.991032   -108.82950932 -109.59604144 -107.98873938 -113.32827147
#  -106.73920797 -106.9226473  -106.91719226 -106.76823452 -107.20690536], blobs=None, random_state=('MT19937', array([4146356013, 1979163317, 1229258230, 2758151640, 2023557263,
#        3779435051, 2033175925, 2117866769,  942083116, 3461523326,
#        1988884142, 2885376513,  191304448, 2421201605, 4074404670,
#        3454635998, 3575967051,  872458914,   16455359, 3299093889,
#        3316833186, 2844876986, 3764117171, 3470127139, 1194799492,
#        3764181584, 1140552131, 3312815525, 2825392661, 1779073816,
#        2567734780, 1098416231, 2699249154,  289116262,  679670458,
#         469284329, 1320308099, 1298428708, 1356372597, 1722182150,
#        1722715847,  203011723, 1874867299, 2856459651,  403816635,
#        4080591690, 2283065045, 1663477201, 2030881133, 3482466974,
#         641579796, 1281789051, 2002752383, 3319619901, 2403140001,
#        2041726055, 1792905243, 4294336892, 2524975776, 3835251075,
#         361435861,  118982226, 2417652279,  733163752, 3354562841,
#        1088665080, 2635933591, 3720430741, 1399566849,  822741489,
#        3379933188, 1391342327, 3441665334,  894792800, 3668246231,
#        1666979660,  770448023, 3026319804, 3360627182, 3578662266,
#        1803978435,  286018139, 1711552881, 2309883540, 3841639568,
#         164302216, 3207615317, 1339348462,  167906727, 1224577695,
#         818746016, 3840872127,  808122813, 1614674766, 3920486461,
#        3245223665, 3988616252, 3770528764, 4174384868, 3577763319,
#        2795980036,  471364891, 3495589668, 2287560703, 2833615021,
#        2292296704, 1342219652, 1650235440,  974342063, 2405767265,
#        1931650947,  210713093, 1198838991, 1709751762, 3089237956,
#         163522689, 3899251673, 4250624706, 2462225627,  562159738,
#        4008102240, 3151945711, 1052280740,  240139581,  887761860,
#        2434296878, 1785220965,  967505420, 2401416228,  463040770,
#         701312844, 2227430173, 2487058222, 4042449021, 1566900300,
#        1332508921, 2680759035, 2110377782, 3448669777,  666913314,
#        4111991027, 2624324243, 1875133347, 3143004000, 4045192788,
#        3958417877, 2410431110, 3588376445, 1367078503,  993349578,
#        4158490527, 3772186796, 4241342138, 1059581375, 4186634920,
#        3157274717,  968564997,  545051446, 3520637753, 3639446969,
#         573901462,  871764135, 1634241643, 2702368857, 2073989399,
#        2539707486,   89269404, 2136292292,  703628523,   17344394,
#        1754986073, 1107757315, 2912269096, 1160630018,  824187365,
#        1666383110, 2857354586, 1372093323, 1551494968,  284387609,
#        3739797396, 1713721065, 1326719019, 1407462613, 2389058493,
#         930066900, 2599867205, 2802956110, 2078257864, 1783143129,
#         107386851, 2831497417,  548406564,  537249911, 1253888566,
#        3130567469,  925441469, 1474911528, 3134199741, 1609207878,
#        2436358521, 3839384147, 1366251170,    7682728, 3339504334,
#        2866202190, 2311890053, 3809444568, 3257361113, 3534546573,
#        1436055449, 1222525179, 3529847893,  766906814, 1468694864,
#        4093424719, 1397609130, 2968407634, 2496512862, 2534556785,
#        1672216805, 3587068713, 1202408148, 2440606939,  448981225,
#        3166953994, 3745823605, 2914099357,  401706659, 2518161577,
#         653515588, 1162369484, 3415400534, 1285806663,  284290483,
#        4073428089, 2951834835, 2307622545,  255800938, 2356399074,
#        3560403201,  858378212, 1645084396, 1432404750, 1108294251,
#        3105737246, 1882661029,  322709883, 1238063759, 2989179935,
#        3640836722,  111869427, 2845931111, 3902740402,  694011560,
#        2446364934, 4291248377, 4243854498, 3684921063, 1420825429,
#        1305720624, 2162827285, 3517009663, 3334465257, 3159442637,
#        4271924636,  621934661, 3050375226, 1493624817,  603908780,
#        1177256485, 1641623474, 3421083154, 2808258245, 2102999411,
#        1095196605,   66636103, 1824330848, 2202452969, 3787076124,
#        2313872748, 3744238161, 3896035129,  791442516, 4286586469,
#        3328115915, 2865655797, 2924865986,  534574887, 4268224029,
#        1485491116,  701202735,    3824017, 1057952050, 4182988320,
#        2312642445, 1290841109, 1143463041, 4293022534,  236833711,
#         318294835, 1521198385, 3506130083, 3120478579,  192982504,
#        1289785789, 4272885322, 4039392560,  930473795, 3074490684,
#        2552627600, 3838289374, 2637253733, 3016008101, 3469941465,
#        4144656140, 3210853841, 3064102212, 1452156957, 3785119897,
#         159458862, 3786324227, 3319638174, 1375301740, 4185300373,
#        3390261376, 1752233153, 2086006805,  600944722, 3070266187,
#        4177174775, 2676371376,  676022961, 2877580208, 2079789513,
#        3687512418, 1577064992, 2464297203, 3381738215,  365113638,
#        3677140366, 1233982938, 3454517079, 2084745091, 1768356788,
#          83210807, 2137680479, 4080356394, 2237742693, 2157223562,
#        2308213551, 1774845122,  545369656, 2201160576,  498093977,
#         193972944, 1898474679, 1796169708, 1926485207, 4256028861,
#         639625990, 4035042232, 4224285350, 4174460610, 3239015313,
#        3171315809, 3869833697, 3635149371,  960809873,  384393516,
#        1226706761, 2524279156, 2969654929, 3131226361,  604665206,
#        1875901935, 1677236446, 2335819844, 3857942750,  298067298,
#        1717086643,   26810760, 3544775037, 1741724650, 1660908638,
#        1252306125, 1416828676, 1258097400, 3699980060, 1324574997,
#        1372610600, 1723191341, 3476816611, 1471116576, 2769400325,
#        3733504450,   26368235,  681463605, 1731199259,  494812270,
#        2100628916,   52295779, 2393730387, 2899437890, 3960371879,
#        1409153051, 3930634011,  221754341, 1938172187, 4066356402,
#        3303827006, 1861942284, 3582687648, 2040192531, 3053175358,
#        3906175653, 1728771093, 2152496006, 3710979826, 1581316567,
#        2616813775, 4139980897, 1139658821, 3278308958,  479737837,
#        1041724441, 3514355125, 2796446231, 4260078614, 2808397983,
#        2884873482,  283458267, 2209104388, 2224201248,  375830038,
#        3452148688, 1666488777, 2650104165, 3716183428,  982635625,
#        2494841070, 1164983143, 4263943409, 2103883810, 1489601084,
#        1387179351, 2676285363, 2495979682, 3479121079,  622978022,
#         946861705, 1824777320, 3420499648, 3167058121, 2874233762,
#        1921353690, 1687383931, 2130222542, 2870956052, 3662486611,
#        4063255459, 2254094332, 4059927217, 1537524466, 1854896902,
#        1237190611, 1674700175,  629406117, 4094228157, 1341980888,
#         521245278, 2289058311,  488493711,  736665759, 3126981522,
#        1472417884, 4285787603,  813934401, 1411767153, 1542534910,
#        3055364338,  910013678, 1318694607, 3286721114, 2491010364,
#        2211946031,  853882685, 4053424327,  896040953, 1389942551,
#        2782899119, 3620363044, 3770149592, 1519018900, 3878539695,
#         872143540, 4237692242,  973462183, 2504852585, 2756541843,
#        3680840197, 3552703558, 3076656427, 1137785025, 1504595473,
#         259222710,  308407545, 3245815516, 1828609165, 2994478149,
#        2870700075, 4153841516, 1047064516,   44732763, 2466174011,
#        4147158126,  202942756, 2682356400, 1486903314, 3306880127,
#        1520074158,  275357623, 3798595041, 4192134203, 3122535652,
#        1859030791, 3569668193, 1377333308,  301033610, 1463827733,
#        3855744669, 4087002766, 3013596936, 4188680748, 2618479263,
#        2947548745, 1460283052, 1916263255, 1724226289, 2107523181,
#        1066402276,  390010365, 2839868811, 4081210816, 1322055837,
#        1222459384,   87579339,  285957490,  875236565,  881871384,
#        2203124605, 2671889097,  654848003, 3366108190,   37476346,
#        2307552816, 2749629857, 2206478432, 2364327214, 4288121210,
#        1064696321, 2954003127, 2145811048, 2717936522,  830672687,
#        1849298998, 4068398503, 1444736836,  663040788, 2352812681,
#        2396648451,  551747723, 3590888451,  963727560, 2445117194,
#        2762361778, 2493672597,  679709582, 4142476909, 2403863059,
#        2185981484, 2524637826, 1888500146, 2230995632, 2257610950,
#        1825867146,  713796168, 3536997589,   16901372, 1910776735,
#        2110675774, 3338142932, 1244549721, 4279559112, 1277565452,
#        2341931015, 2082761377, 2315085538, 2877369235, 2489516794,
#        3793170942,  219792710, 2045247305, 1797784012, 1360514951,
#        1175926652, 3594180419, 3844790222, 3505848910,  437725997,
#         614862252, 1315785986, 2462939458, 1276797282, 2680261677,
#         143667738, 3641799305, 1320284203, 1888644000,  392146687,
#          49247440,  389543542, 1986861060, 3809003426], dtype=uint32), 306, 0, 0.0))

# %% [markdown]
# **Get the $\lambda$ and $k$ samples** from the sampler in arrays called `λ_sample` and `k_sample`,
#
# Then **Compute the MAP** (maximum a posterior estimate) of $\lambda$ and $k$ and set them to `λ_hat_mcmc` and `k_hat_mcmc`.
# Then print them together with the MLE for comparison.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 3), sharex=True)

for i, label in enumerate(['λ', 'k']):
    for j in range(nwalkers):
        axes[i].plot(sampler.chain[j, :, i])
        axes[i].set_ylabel(label)
fig.tight_layout()

# %%
λ_sample = sampler.chain[:, -1, 0]
k_sample = sampler.chain[:, -1, 1]
λ_hat_mcmc = λ_sample.mean()
k_hat_mcmc = k_sample.mean()

print('MLE:  λ_hat = {:.2f}, k_hat={:.2f}'.format(λ_hat, k_hat)) ### 
print('MCMC: λ_hat = {:.2f}, k_hat={:.2f}'.format(λ_hat_mcmc, k_hat_mcmc)) ###
# Out:
# MLE:  λ_hat = 9.48, k_hat=1.72
# MCMC: λ_hat = 9.65, k_hat=1.76

# %% [markdown]
# We plot a trace plot of both $\lambda$ and $k$.

# %%
fig, axes = plt.subplots(2, 1, figsize=(6, 6))
axes[0].plot(λ_sample)
axes[0].axhline(λ_hat_mcmc, color=red)
axes[1].plot(k_sample)
axes[1].axhline(k_hat_mcmc, color=red)
axes[0].set(ylabel='λ')
axes[1].set(xlabel='Iteration', ylabel='k')
fig.tight_layout()
sns.despine()

# %% [markdown]
# **Plot the marginal and joint posterior distribution**.
# Add lines and markers to show the MAP (red) and MLE (green).

# %%
sample = sampler.chain[:, nburn:, :].ravel().reshape(-1, ndim)
cor = corner(sample, 
    smooth=True,
    labels=['λ', 'k'],
    show_titles=True,
)
cor.axes[0].axvline(λ_hat_mcmc, color=red)
cor.axes[3].axvline(k_hat_mcmc, color=red)
cor.axes[2].plot(λ_hat_mcmc, k_hat_mcmc, 'o', color=red);
cor.axes[0].axvline(λ_hat, color=green)
cor.axes[3].axvline(k_hat, color=green)
cor.axes[2].plot(λ_hat, k_hat, 'o', color=green);

# %% [markdown]
# Now, we plot the survival function that gives the probability of survival after $x$ days (for a hospitalized patient that will eventually die in the hospital, so this is conditioned on death, like all our analysis).
#
# The survival function is the complement of the cumulative distribution function. It can be written as:
# $$
# s(x) = \exp\Big[{-\big(\frac{x}{\lambda}\big)^k}\Big],
# $$
# where $x$ is the number of days since hospitalization and $s(x)$ is the probability to survive $x$ days.
#
# In addition, we print the median number of days before death conditioned on eventual death.

# %%
def survival_probability(θ, x):
    λ, k = θ
    return np.exp(-(x/λ)**k)

x_range = np.linspace(0, 31)
plt.plot(x_range, survival_probability((λ_hat_mcmc, k_hat_mcmc), x_range), lw=2)
plt.xlim(0, 30)
plt.ylim(0, 1)
plt.ylabel('Survival probability')
plt.xlabel('Days in hospital')

median = λ_hat_mcmc * np.log(2)**(1/k_hat_mcmc)
print("Median survival days: {:.2f}".format(median)) ###
# Out:
# Median survival days: 7.84

# %% [markdown]
# **End of assignment**
